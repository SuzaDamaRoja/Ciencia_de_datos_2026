# %% [markdown]
# #Ejercicio de ingreso
#
# Agenda
# 1. Inserción de bloques de texto
# 2. Inserción de títulos
# 3. Trabajando con el bloque de código

# %% [markdown]
# ##Limpieza de datos

# %% [markdown]
# Se aprende a usar el comando print y el uso de comentarios

# %%
#Este e un comentario
print("Hola extraterretres 👽")
# Out:
# Hola extraterretres 👽

# %% [markdown]
# ##Selección de datos
